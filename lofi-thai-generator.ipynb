# %%
import glob
import pickle
import numpy
from music21 import converter, instrument, note, chord
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Activation, BatchNormalization as BatchNorm
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
def train_network():
    """ Train a Neural Network to generate music"""
    notes = get_notes()
    
    print(notes)
    # get amount of pitch names
    n_vocab = len(set(notes))
    
#     network_input, network_output = prepare_sequences(notes, n_vocab)
    
#     model = create_network(network_input, n_vocab)
    
#     train(model, network_input, network_output)

# %%
def get_notes():
    """ Get all the notes and chords from the midi files in the ./midi_songs directory """
    notes = []
    
    for file in glob.glob("midi_songs/*.mid"):
        midi = converter.parse(file)
        
        print("Parsing %s" % file)
        
        notes_to_parse = None
        
        try: # file has instrument parts
            s2 = instrument.partitionByInstrument(midi)
            notes_to_parse = s2.parts[0].recurse()
        except: # file has notes in a flat structure
            notes_to_parse = midi.flat.notes
            
        for element in notes_to_parse:
            if isinstance(element, note.Note):
                notes.append(str(element.pitch))
            elif isinstance(element, chord.Chord):
                notes.append('.'.join(str(n) for n in element.normalOrder))
    
    with open('data/notes', 'wb') as filepath:
        pickle.dump(notes, filepath)
        
    return notes

# %%
def prepare_sequences(notes, n_vocab):
    """ Prepare the sequences used by the Neural Network """
    sequence_length = 32
    
    # get all pitch names
    pitchnames = sorted(set(item for item in notes))
    
    # create a dictionary to map pitches to integers
    note_to_int = dict((note, number) for number, note in enumerate(pitchnames))
    
    network_input = []
    network_output = []
    
    # create input sequences and the corresponding outputs
    for i in range(0, len(notes) - sequence_length, 1):
        sequence_in = notes[i:i + sequence_length]
        sequence_out = notes[i + sequence_length]
        network_input.append([note_to_int[char] for char in sequence_in])
        network_output.append(note_to_int[sequence_out])
        
    n_patterns = len(network_input)
    
    # reshape the input into a format compatible with LSTM layers
    network_input = numpy.reshape(network_input, (n_patterns, sequence_length, 1))
    
    # normalize input
    network_input = network_input / float(n_vocab)
    
    return (network_input, network_output)

# %%
def create_network(network_input, n_vocab):
    """ Create the structure of the neural network """
    model = Sequential()
    model.add(LSTM(
        512,
        input_shape=(network_input.shape[1], network_input.shape[2]),
        recurrent_dropout=0.3,
        return_sequences=True
    ))
    model.add(LSTM(512, return_sequences=True, recurrent_dropout=0.3,))
    model.add(LSTM(512))
    model.add(BatchNorm())
    model.add(Dropout(0.3))
    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(BatchNorm())
    model.add(Dropout(0.3))
    model.add(Dense(n_vocab))
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    
    model.load_weights('lofi-hip-hop-weights-improvement-100-0.6290.hdf5')
    
    return model

# %%
def train(model, network_inpu, network_output):
    """ Train the neural network """
    filepath = "updated-lofi-hip-hop-weights-improvement-1{epoch:02d}-{loss:.4f}.hdf5"
    checkpoint = ModelCheckpoint(
        filepath,
        monitor='loass',
        verbose=0,
        save_best_only=True,
        mode='min'
    )
    callbacks_list = [checkpoint]
    
    model.fit(network_input, network_output, epochs=100, batch_size=64, callbacks=callbacks_list)

# %%
train_network()
# Out:
# Parsing midi_songs/Piano MIDI (2).mid
# Parsing midi_songs/Cymatics - Lofi MIDI 15 - F# Maj.mid
# Parsing midi_songs/Rhodes MIDI (7).mid
# Parsing midi_songs/Cymatics - Eternity MIDI 11 - A Maj.mid
# Parsing midi_songs/Cymatics - Eternity MIDI 7 - E Min.mid
# Parsing midi_songs/Rhodes MIDI (6).mid
# Parsing midi_songs/Cymatics - Lofi MIDI 13 - E Min.mid
# Parsing midi_songs/Cymatics - Lofi MIDI 18 - G Maj.mid
# Parsing midi_songs/Cymatics - Lofi MIDI 3 - C# Min.mid
# Parsing midi_songs/9.mid
# Parsing midi_songs/Piano MIDI (3).mid
# Parsing midi_songs/8.mid
# Parsing midi_songs/Cymatics - Eternity MIDI 3 - D Maj.mid
# Parsing midi_songs/Cymatics - Lofi MIDI 7 - D# Maj.mid
# Parsing midi_songs/Piano MIDI.mid
# Parsing midi_songs/Cymatics - Eternity MIDI 15 - A# Maj.mid
# Parsing midi_songs/16.mid
# Parsing midi_songs/Cymatics - Eternity MIDI 18 - A# Maj.mid
# Parsing midi_songs/Piano MIDI (4).mid
# Parsing midi_songs/Cymatics - Eternity MIDI 22 - B Min.mid
# Parsing midi_songs/Cymatics - Lofi MIDI 10 - D# Maj.mid
# Parsing midi_songs/Lofi Piano MIDI.mid
# Parsing midi_songs/Rhodes MIDI.mid
# Parsing midi_songs/17.mid
# Parsing midi_songs/Piano Chords MIDI (3).mid
# Parsing midi_songs/15.mid
# Parsing midi_songs/Cymatics - Lofi MIDI 11 - E Maj.mid
# Parsing midi_songs/Piano MIDI (8).mid
# Parsing midi_songs/Cymatics - Eternity MIDI 20 - A# Min.mid
# Parsing midi_songs/14.mid
# Parsing midi_songs/Piano 2 MIDI.mid
# Parsing midi_songs/10.mid
# Parsing midi_songs/Cymatics - Eternity MIDI 13 - A Min.mid
# Parsing midi_songs/11.mid
# Parsing midi_songs/Cymatics - Lofi MIDI 5 - D Maj.mid
# Parsing midi_songs/Piano Chords MIDI (2).mid
# Parsing midi_songs/Cymatics - Eternity MIDI 21 - A# Min.mid
# Parsing midi_songs/Cymatics - Lofi MIDI 1 - C# Maj.mid
# Parsing midi_songs/13.mid
# Parsing midi_songs/Cymatics - Eternity MIDI 1 - C Maj.mid
# Parsing midi_songs/Piano MIDI (5).mid
# Parsing midi_songs/Cymatics - Lofi MIDI 17 - G Maj.mid
# Parsing midi_songs/12.mid
# Parsing midi_songs/Rhodes MIDI (3).mid
# Parsing midi_songs/Cymatics - Lofi MIDI 14 - F Min.mid
# Parsing midi_songs/Piano MIDI (6).mid
# Parsing midi_songs/Cymatics - Eternity MIDI 10 - F Min.mid
# Parsing midi_songs/Cymatics - Lofi MIDI 9 - D# Maj.mid
# Parsing midi_songs/E-Piano MIDI.mid
# Parsing midi_songs/Cymatics - Eternity MIDI 2 - C# Min.mid
# Parsing midi_songs/E-Piano Chords MIDI.mid
# Parsing midi_songs/20.mid
# Parsing midi_songs/Cymatics - Eternity MIDI 9 - F Min.mid
# Parsing midi_songs/Cymatics - Lofi MIDI 19 - G Maj.mid
# Parsing midi_songs/Cymatics - Lofi MIDI 12 - E Min.mid
# Parsing midi_songs/Cymatics - Eternity MIDI 14 - A Min.mid
# Parsing midi_songs/Cymatics - Eternity MIDI 8 - F Maj.mid
# Parsing midi_songs/Piano Chords MIDI.mid
# Parsing midi_songs/Cymatics - Lofi MIDI 6 - D Min.mid
# Parsing midi_songs/19.mid
# Parsing midi_songs/Cymatics - Lofi MIDI 8 - D# Maj.mid
# Parsing midi_songs/Cymatics - Eternity MIDI 6 - D Min.mid
# Parsing midi_songs/18.mid
# Parsing midi_songs/E-Piano MIDI (2).mid
# Parsing midi_songs/Piano MIDI (7).mid
# Parsing midi_songs/Cymatics - Lofi MIDI 2 - C# Maj.mid
# Parsing midi_songs/Rhodes MIDI (2).mid
# Parsing midi_songs/Rhodes MIDI (9).mid
# Parsing midi_songs/6.mid
# Parsing midi_songs/Cymatics - Lofi MIDI 22 - B Min.mid
# Parsing midi_songs/Piano MIDI 1.mid
# Parsing midi_songs/7.mid
# Parsing midi_songs/Cymatics - Lofi MIDI 16 - F# Maj.mid
# Parsing midi_songs/Rhodes MIDI (5).mid
# Parsing midi_songs/Piano 1 MIDI.mid
# Parsing midi_songs/Cymatics - Eternity MIDI 12 - A Min.mid
# Parsing midi_songs/Cymatics - Lofi MIDI 4 - D Maj.mid
# Parsing midi_songs/Cymatics - Eternity MIDI 5 - D Min.mid
# Parsing midi_songs/5.mid
# Parsing midi_songs/Cymatics - Eternity MIDI 17 - A# Maj.mid
# Parsing midi_songs/Piano MIDI 2.mid
# Parsing midi_songs/4.mid
# Parsing midi_songs/Cymatics - Eternity MIDI 19 - A# Min.mid
# Parsing midi_songs/Cymatics - Eternity MIDI 4 - D Maj.mid
# Parsing midi_songs/Cymatics - Lofi MIDI 21 - A Min.mid
# Parsing midi_songs/merge_from_ofoct.mid
# Parsing midi_songs/1.mid
# Parsing midi_songs/Rhodes MIDI (4).mid
# Parsing midi_songs/Cymatics - Eternity MIDI 16 - A# Maj.mid
# Parsing midi_songs/3.mid
# Parsing midi_songs/Cymatics - Lofi MIDI 20 - G Min.mid
# Parsing midi_songs/2.mid
# Parsing midi_songs/Rhodes MIDI (8).mid
# ['3', 'G3', 'E-3', '10.2', 'G3', '10.2', 'C2', '7.10.0.3', 'B-1', 'B-2', 'D3', 'A3', 'F3', 'E-2', '3.7', 'D4', 'E-5', 'G5', '10.2', 'C2', '0.3', '0.3', '7', '10', '10', 'B-4', '2', '9', 'F5', '11.2.6', 'A4', 'D5', '7.9.0', 'E4', 'C5', '0.4.7', 'B4', 'F#5', 'E5', 'D5', 'B4', '11.2.6', 'A4', 'D5', '4.7', 'C4', 'G4', '0.4.7', 'B4', '7.11.2', 'F#4', 'G#3', 'B3', '3.6', 'E-4', 'B3', '8.11', '3.6', 'F#1', '9.11.4', '1', '11', '9.11.1.4', 'C#4', '9.11.1.4', '9', '8.11.1.4', '11.1', '1', '7.10.0.3', 'C#4', 'B1', '2.6.9', '4', 'C#4', '11', 'C#4', 'D2', '6.9.1', 'C#4', 'C#4', '9', 'F#1', '9.11.4', '1', '11', '9.11.1.4', 'C#4', '9.11.1.4', '9', '8.11.1.4', '11.1', '1', '7.10.0.3', 'C#4', 'B1', '2.6.9', '4', 'C#4', '6', 'C#4', 'D2', '6.9.1', '1.4', '9.1', '11.4', '7', 'F#4', 'G3', 'D5', 'B5', '11.0', '9.2', '7.11.2', 'F#4', '7.11.2', '7.0', '9.0', '0.4.7', '7', 'F#4', 'B3', 'D5', 'B5', 'G3', 'C5', '0.2', '7.9', 'C4', 'D5', 'B3', 'F#4', 'A3', 'D4', 'B5', '7.0', 'G5', '11.4', '7', 'F#4', 'G3', 'D5', '11.0', '9.2', '7.11.2', 'F#4', '11.2', '7.0', 'C5', '0.4.7', 'G4', 'F#4', 'B3', 'D5', 'G3', 'C5', '0.2', '7.9', 'C4', 'B3', 'F#4', 'A3', 'D4', '7.0', 'A3', 'B3', 'D4', 'E4', 'F#4', 'G4', 'F#4', 'G4', 'F#4', 'E4', 'D4', 'A3', 'B3', 'E3', 'E4', 'G7', 'G4', 'B4', 'D5', 'E5', 'G5', 'B5', 'D6', 'G6', 'B7', 'F#6', 'C8', 'B6', 'D8', 'E6', '0.4', 'C4', 'E4', 'G4', 'B4', 'C5', 'E5', 'G5', 'B5', 'E6', 'D6', 'G6', 'B5', 'E3', 'E4', 'G7', 'G4', 'B4', 'D5', 'E5', 'G5', 'B5', 'D6', 'G6', 'B7', 'F#6', 'C8', '0.2.4', '2.8', '9.0', 'C4', 'A8', 'E4', 'G4', 'B4', 'C5', 'E5', 'G5', 'B5', 'E6', 'D6', '7.11', 'G3', 'B4', 'D5', '2.6', 'F#5', 'B4', 'D5', '11.2', '6.9', 'C#5', 'B4', 'F#5', 'E3', 'B4', 'D5', '2.6', 'F#5', 'B4', 'D5', '2.6', 'F#4', 'A4', 'C#5', 'B4', 'F#5', 'B4', 'A4', 'F#5', 'E5', 'G3', 'B4', 'D5', '2.6', 'F#5', 'B4', 'D5', '11.2', '6.9', 'C#5', 'B4', 'F#5', 'E3', 'B4', 'D5', '2.6', 'F#5', 'B4', 'D5', '2.6', 'F#4', 'A4', 'C#5', 'B4', 'F#5', 'B4', 'A4', 'F#5', 'E5', '1.4', '8.1', 'F#5', 'A5', 'G#5', 'F#5', 'B3', 'E-4', '6.11', '8.11', 'E5', '3.8', 'G#5', 'F#5', 'E5', '1.4.6.9', 'F#4', '3.6.8.11', '8.9.1.4', '4.7.9.11.0', 'E4', 'G4', 'A5', 'E5', 'A4', '4.5.9.0', 'A4', '2.4.7.9', '4.7.9.0', 'A4', '4.7.9.11.0', 'E4', 'G4', 'A5', 'E5', 'A4', '4.5.9.0', 'A4', '2.4.7.9', '4.7.9.0', 'A4', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'B4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'B4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'B4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'B4', 'E3', '4.7.11', 'E4', 'G4', 'E5', '11.2', '6.9', 'F#4', 'F#5', 'E5', 'G5', 'B5', '4.7', 'B3', 'E4', 'G4', 'E5', '11.2.6', 'A5', 'F#4', 'F#5', 'E5', 'G5', 'B5', 'D2', '2.6.9', 'C#4', 'D3', 'F#3', 'A3', 'E4', '1.6', 'D3', 'A2', '7.11.1', 'E4', '7.11', '1.7', '6.9.10', '6.7.10.1', '6.11', 'A3', '1.2.6', 'A3', '1.2.6', 'A3', 'A2', 'G2', '11.2', 'G3', 'G3', '2.6.9', '2.6.9', 'G3', '2.6.9', 'G2', 'D2', '2.6.9', 'C#4', 'D3', 'F#3', 'A3', 'E4', '1.6', 'D3', 'A2', '7.11.1', 'E4', '7.11', '1.7', '6.9.10', '6.7.10.1', '6.11', 'A3', '1.2.6', 'A3', '1.2.6', 'A3', 'A2', 'G2', '11.2', 'G3', 'G3', '2.6.9', '2.6.9', 'G3', '2.6.9', 'G2', '8.11.3', 'F#4', 'B4', 'E5', 'E-5', 'G#4', 'F#4', 'C#4', '8.9.11.1.4', '1.4.6.8.9', '8.11.3', 'F#4', 'B4', 'E5', 'E-5', 'G#4', 'F#4', 'C#4', '8.9.11.1.4', '1.4.6.8.9', '3.6.8.11', 'C#5', 'B-4', 'C#5', 'B-4', 'C#5', 'B-4', 'C#5', 'B-4', 'C#5', 'B-4', 'C#5', 'B-4', 'C#5', 'B-4', 'C#5', 'B-4', 'C#5', 'B-4', 'C#5', 'B-4', 'C#5', 'B-4', 'C#5', 'B-4', 'C#5', 'B-4', 'C#5', 'B-4', 'C#5', 'B-4', 'C#5', 'B-4', 'E-5', 'F5', 'G#5', 'B-5', 'G#5', 'F5', '1.3', 'F5', 'E-5', 'C#5', 'B-4', 'G#4', 'B-4', 'C#5', 'E-5', 'F5', 'G#5', 'B-5', 'C#6', 'E-6', 'F6', 'B-6', 'G#6', 'F6', 'E-6', 'F6', 'E-6', 'C#6', 'B-5', 'G#5', 'F5', 'E-5', 'F5', 'E-5', 'C#5', 'B-4', 'G#4', 'F4', 'C3', 'E-5' ...
